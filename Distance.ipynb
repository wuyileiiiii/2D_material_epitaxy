# %%
import re
import numpy as np
import collections
from ase.io import read
from ase.atoms import Atoms

# %%
def read_atom(poscar_file, twoDmaterials_elements, substrate_elements):
    atoms = read(poscar_file)
    atoms.set_pbc([True, True, False])
    all_elements = list(set(atoms.get_chemical_symbols()))
    print(f"Elements in POSCAR: {all_elements}")

    atoms_by_element = collections.defaultdict(list)
    twoDmaterials_atoms = []
    substrate_atoms = []

    for index, atom in enumerate(atoms):
        if atom.symbol in twoDmaterials_elements:
            twoDmaterials_atoms.append((atom, index))
        elif atom.symbol in substrate_elements:
            substrate_atoms.append((atom, index))

    return twoDmaterials_atoms, substrate_atoms, atoms

# %%
def identify(twoDmaterials_atoms, substrate_atoms, tolerance=0.1):
    twoDmaterials_bottom_layer = []
    substrate_top_layer = []
    twoDmaterials_bottom_layer_idx = []
    substrate_top_layer_idx = []
    

    if twoDmaterials_atoms:
        twoDmaterials_zcoords = np.array([atom_obj.position[2] for atom_obj, _ in twoDmaterials_atoms])
        min_twoD_position = np.min(twoDmaterials_zcoords)

        for atom_obj, original_idx in twoDmaterials_atoms: # 遍历 (Atom对象, 原始索引) 元组
            if abs(atom_obj.position[2] - min_twoD_position) < tolerance:
                twoDmaterials_bottom_layer.append((atom_obj, original_idx)) # 存储 (Atom对象, 原始索引)
                twoDmaterials_bottom_layer_idx.append(original_idx)
    else:
        print("No 2D material atoms provided to identify bottom layer.")

    # Process substrate atoms
    if substrate_atoms:
        substrate_z_coords = np.array([atom_obj.position[2] for atom_obj, _ in substrate_atoms])
        max_substrate_z = np.max(substrate_z_coords)

        for atom_obj, original_idx in substrate_atoms: # 遍历 (Atom对象, 原始索引) 元组
            if abs(atom_obj.position[2] - max_substrate_z) < tolerance:
                substrate_top_layer.append((atom_obj, original_idx)) # 存储 (Atom对象, 原始索引)
                substrate_top_layer_idx.append(original_idx)
    else:
        print("No substrate atoms provided to identify top layer.")

    return twoDmaterials_bottom_layer_idx, substrate_top_layer_idx

# %%
def calculate(twoDmaterials_bottom_layer_idx, substrate_top_layer_idx, interface_system_atoms):

    closest_distances_for_each_2d_atom = []
    calculated_pair_indices = [] 
    
    # Iterate through each atom in the 2D material's bottom layer
    for two_d_atom_indices in twoDmaterials_bottom_layer_idx:
        min_dist_for_current_2d_atom = float('inf') # Initialize with a very large number
        closest_sub_atom_idx = None
        
        # Compare it to every atom in the substrate's top layer
        for sub_atom_indices in substrate_top_layer_idx:
            # Calculate the Euclidean distance between the two atoms
            distance = interface_system_atoms.get_distance(two_d_atom_indices, sub_atom_indices, mic=True)

            # Update min_dist if a shorter distance is found
            if distance < min_dist_for_current_2d_atom:
                min_dist_for_current_2d_atom = distance
                closest_sub_atom_idx = sub_atom_indices
                

        # After checking all substrate atoms for the current 2D atom, store its shortest distance
        if min_dist_for_current_2d_atom != float('inf'): # Ensure a valid distance was found
            closest_distances_for_each_2d_atom.append(min_dist_for_current_2d_atom)
            if closest_sub_atom_idx is not None:
                calculated_pair_indices.append((two_d_atom_indices, closest_sub_atom_idx))
                print(f"  - 2D atom index: {two_d_atom_indices} (Symbol: {interface_system_atoms[two_d_atom_indices].symbol}) "
                      f"-> Closest Substrate atom index: {closest_sub_atom_idx} (Symbol: {interface_system_atoms[closest_sub_atom_idx].symbol}), "
                      f"Distance: {min_dist_for_current_2d_atom:.3f} Å")
        else:
            print(f"Warning: Could not find any distance for 2D atom. This should not happen if layers are not empty.")


    if closest_distances_for_each_2d_atom:
        average_closest_distance = np.mean(closest_distances_for_each_2d_atom)
        return average_closest_distance
    else:
        print("No valid shortest distances were found for calculation.")
        return None

# %%
if __name__ == "__main__":
    file_out = open("result.txt",'w',encoding='utf-8')
    for g in range(20):
        for h in range(20):
            poscar_file = "POSCAR_"+str(g)+"_"+str(h)
            print(poscar_file, file = file_out)

            twoDmaterials_elements = ['Mo', 'S']
            substrate_elements = ['Au']

            twoDmaterials_atoms, substrate_atoms, interface_system_atoms = read_atom(poscar_file, twoDmaterials_elements, substrate_elements)
            if twoDmaterials_atoms is not None and substrate_atoms is not None:
                twoDmaterials_bottom_layer_idx, substrate_top_layer_idx = identify(twoDmaterials_atoms, substrate_atoms, tolerance=0.1)
                print("\nCalculating average shortest interfacial distance...")
                average_distance = calculate(twoDmaterials_bottom_layer_idx, substrate_top_layer_idx, interface_system_atoms)

                if average_distance is not None:
                    print(f"Average shortest distance from 2D material bottom layer to substrate top layer: {average_distance:.3f} Å", file = file_out)
                else:
                    print("Failed to calculate average shortest distance.", file = file_out)

            else:
                print("\nAtom categorization failed or no atoms were found for 2D material/substrate. Please check the POSCAR file and element inputs.")
file_out.close()
# Out:
# Elements in POSCAR: ['S', 'Au', 'Mo']
#
# Calculating average shortest interfacial distance...
#   - 2D atom index: 196 (Symbol: S) -> Closest Substrate atom index: 121 (Symbol: Au), Distance: 3.441 Å
#   - 2D atom index: 198 (Symbol: S) -> Closest Substrate atom index: 149 (Symbol: Au), Distance: 3.243 Å
#   - 2D atom index: 200 (Symbol: S) -> Closest Substrate atom index: 121 (Symbol: Au), Distance: 3.350 Å
#   - 2D atom index: 202 (Symbol: S) -> Closest Substrate atom index: 181 (Symbol: Au), Distance: 3.262 Å
#   - 2D atom index: 204 (Symbol: S) -> Closest Substrate atom index: 125 (Symbol: Au), Distance: 3.361 Å
#   - 2D atom index: 206 (Symbol: S) -> Closest Substrate atom index: 153 (Symbol: Au), Distance: 3.298 Å
#   - 2D atom index: 208 (Symbol: S) -> Closest Substrate atom index: 97 (Symbol: Au), Distance: 3.357 Å
#   - 2D atom index: 210 (Symbol: S) -> Closest Substrate atom index: 125 (Symbol: Au), Distance: 3.403 Å
#   - 2D atom index: 212 (Symbol: S) -> Closest Substrate atom index: 185 (Symbol: Au), Distance: 3.203 Å
#   - 2D atom index: 214 (Symbol: S) -> Closest Substrate atom index: 129 (Symbol: Au), Distance: 3.303 Å
#   - 2D atom index: 216 (Symbol: S) -> Closest Substrate atom index: 157 (Symbol: Au), Distance: 3.375 Å
#   - 2D atom index: 218 (Symbol: S) -> Closest Substrate atom index: 101 (Symbol: Au), Distance: 3.299 Å
#   - 2D atom index: 220 (Symbol: S) -> Closest Substrate atom index: 129 (Symbol: Au), Distance: 3.478 Å
#   - 2D atom index: 222 (Symbol: S) -> Closest Substrate atom index: 189 (Symbol: Au), Distance: 3.168 Å
#   - 2D atom index: 224 (Symbol: S) -> Closest Substrate atom index: 133 (Symbol: Au), Distance: 3.270 Å
#   - 2D atom index: 226 (Symbol: S) -> Closest Substrate atom index: 161 (Symbol: Au), Distance: 3.474 Å
#   - 2D atom index: 228 (Symbol: S) -> Closest Substrate atom index: 105 (Symbol: Au), Distance: 3.266 Å
#   - 2D atom index: 230 (Symbol: S) -> Closest Substrate atom index: 133 (Symbol: Au), Distance: 3.574 Å
#   - 2D atom index: 232 (Symbol: S) -> Closest Substrate atom index: 137 (Symbol: Au), Distance: 3.260 Å
# Elements in POSCAR: ['S', 'Au', 'Mo']
#
# Calculating average shortest interfacial distance...
#   - 2D atom index: 196 (Symbol: S) -> Closest Substrate atom index: 149 (Symbol: Au), Distance: 3.233 Å
#   - 2D atom index: 198 (Symbol: S) -> Closest Substrate atom index: 177 (Symbol: Au), Distance: 3.108 Å
#   - 2D atom index: 200 (Symbol: S) -> Closest Substrate atom index: 121 (Symbol: Au), Distance: 3.056 Å
#   - 2D atom index: 202 (Symbol: S) -> Closest Substrate atom index: 13 (Symbol: Au), Distance: 3.210 Å
#   - 2D atom index: 204 (Symbol: S) -> Closest Substrate atom index: 153 (Symbol: Au), Distance: 3.148 Å
#   - 2D atom index: 206 (Symbol: S) -> Closest Substrate atom index: 181 (Symbol: Au), Distance: 3.165 Å
#   - 2D atom index: 208 (Symbol: S) -> Closest Substrate atom index: 97 (Symbol: Au), Distance: 3.110 Å
#   - 2D atom index: 210 (Symbol: S) -> Closest Substrate atom index: 125 (Symbol: Au), Distance: 3.114 Å
#   - 2D atom index: 212 (Symbol: S) -> Closest Substrate atom index: 17 (Symbol: Au), Distance: 3.150 Å
#   - 2D atom index: 214 (Symbol: S) -> Closest Substrate atom index: 157 (Symbol: Au), Distance: 3.087 Å
#   - 2D atom index: 216 (Symbol: S) -> Closest Substrate atom index: 185 (Symbol: Au), Distance: 3.245 Å
#   - 2D atom index: 218 (Symbol: S) -> Closest Substrate atom index: 101 (Symbol: Au), Distance: 3.047 Å
#   - 2D atom index: 220 (Symbol: S) -> Closest Substrate atom index: 129 (Symbol: Au), Distance: 3.196 Å
#   - 2D atom index: 222 (Symbol: S) -> Closest Substrate atom index: 21 (Symbol: Au), Distance: 3.115 Å
#   - 2D atom index: 224 (Symbol: S) -> Closest Substrate atom index: 161 (Symbol: Au), Distance: 3.051 Å
#   - 2D atom index: 226 (Symbol: S) -> Closest Substrate atom index: 189 (Symbol: Au), Distance: 3.348 Å
#   - 2D atom index: 228 (Symbol: S) -> Closest Substrate atom index: 105 (Symbol: Au), Distance: 3.011 Å
#   - 2D atom index: 230 (Symbol: S) -> Closest Substrate atom index: 133 (Symbol: Au), Distance: 3.300 Å
#   - 2D atom index: 232 (Symbol: S) -> Closest Substrate atom index: 165 (Symbol: Au), Distance: 3.041 Å
# Elements in POSCAR: ['S', 'Au', 'Mo']
#
# Calculating average shortest interfacial distance...
#   - 2D atom index: 196 (Symbol: S) -> Closest Substrate atom index: 149 (Symbol: Au), Distance: 3.213 Å
#   - 2D atom index: 198 (Symbol: S) -> Closest Substrate atom index: 177 (Symbol: Au), Distance: 3.041 Å
#   - 2D atom index: 200 (Symbol: S) -> Closest Substrate atom index: 121 (Symbol: Au), Distance: 3.082 Å
#   - 2D atom index: 202 (Symbol: S) -> Closest Substrate atom index: 13 (Symbol: Au), Distance: 3.100 Å
#   - 2D atom index: 204 (Symbol: S) -> Closest Substrate atom index: 153 (Symbol: Au), Distance: 3.128 Å
#   - 2D atom index: 206 (Symbol: S) -> Closest Substrate atom index: 181 (Symbol: Au), Distance: 3.099 Å
#   - 2D atom index: 208 (Symbol: S) -> Closest Substrate atom index: 97 (Symbol: Au), Distance: 3.179 Å
#   - 2D atom index: 210 (Symbol: S) -> Closest Substrate atom index: 125 (Symbol: Au), Distance: 3.139 Å
#   - 2D atom index: 212 (Symbol: S) -> Closest Substrate atom index: 17 (Symbol: Au), Distance: 3.038 Å
#   - 2D atom index: 214 (Symbol: S) -> Closest Substrate atom index: 157 (Symbol: Au), Distance: 3.066 Å
#   - 2D atom index: 216 (Symbol: S) -> Closest Substrate atom index: 185 (Symbol: Au), Distance: 3.182 Å
#   - 2D atom index: 218 (Symbol: S) -> Closest Substrate atom index: 101 (Symbol: Au), Distance: 3.119 Å
#   - 2D atom index: 220 (Symbol: S) -> Closest Substrate atom index: 129 (Symbol: Au), Distance: 3.220 Å
#   - 2D atom index: 222 (Symbol: S) -> Closest Substrate atom index: 21 (Symbol: Au), Distance: 3.002 Å
#   - 2D atom index: 224 (Symbol: S) -> Closest Substrate atom index: 161 (Symbol: Au), Distance: 3.030 Å
#   - 2D atom index: 226 (Symbol: S) -> Closest Substrate atom index: 189 (Symbol: Au), Distance: 3.287 Å
#   - 2D atom index: 228 (Symbol: S) -> Closest Substrate atom index: 105 (Symbol: Au), Distance: 3.083 Å
#   - 2D atom index: 230 (Symbol: S) -> Closest Substrate atom index: 133 (Symbol: Au), Distance: 3.324 Å
#   - 2D atom index: 232 (Symbol: S) -> Closest Substrate atom index: 165 (Symbol: Au), Distance: 3.020 Å
# Elements in POSCAR: ['S', 'Au', 'Mo']
#
# Calculating average shortest interfacial distance...
#   - 2D atom index: 196 (Symbol: S) -> Closest Substrate atom index: 177 (Symbol: Au), Distance: 3.491 Å
#   - 2D atom index: 198 (Symbol: S) -> Closest Substrate atom index: 177 (Symbol: Au), Distance: 3.298 Å
#   - 2D atom index: 200 (Symbol: S) -> Closest Substrate atom index: 149 (Symbol: Au), Distance: 3.291 Å
#   - 2D atom index: 202 (Symbol: S) -> Closest Substrate atom index: 13 (Symbol: Au), Distance: 3.310 Å
#   - 2D atom index: 204 (Symbol: S) -> Closest Substrate atom index: 181 (Symbol: Au), Distance: 3.412 Å
#   - 2D atom index: 206 (Symbol: S) -> Closest Substrate atom index: 181 (Symbol: Au), Distance: 3.351 Å
#   - 2D atom index: 208 (Symbol: S) -> Closest Substrate atom index: 125 (Symbol: Au), Distance: 3.304 Å
#   - 2D atom index: 210 (Symbol: S) -> Closest Substrate atom index: 153 (Symbol: Au), Distance: 3.344 Å
#   - 2D atom index: 212 (Symbol: S) -> Closest Substrate atom index: 17 (Symbol: Au), Distance: 3.252 Å
#   - 2D atom index: 214 (Symbol: S) -> Closest Substrate atom index: 185 (Symbol: Au), Distance: 3.355 Å
#   - 2D atom index: 216 (Symbol: S) -> Closest Substrate atom index: 185 (Symbol: Au), Distance: 3.428 Å
#   - 2D atom index: 218 (Symbol: S) -> Closest Substrate atom index: 129 (Symbol: Au), Distance: 3.245 Å
#   - 2D atom index: 220 (Symbol: S) -> Closest Substrate atom index: 157 (Symbol: Au), Distance: 3.421 Å
#   - 2D atom index: 222 (Symbol: S) -> Closest Substrate atom index: 21 (Symbol: Au), Distance: 3.217 Å
#   - 2D atom index: 224 (Symbol: S) -> Closest Substrate atom index: 189 (Symbol: Au), Distance: 3.322 Å
#   - 2D atom index: 226 (Symbol: S) -> Closest Substrate atom index: 189 (Symbol: Au), Distance: 3.525 Å
#   - 2D atom index: 228 (Symbol: S) -> Closest Substrate atom index: 133 (Symbol: Au), Distance: 3.211 Å
#   - 2D atom index: 230 (Symbol: S) -> Closest Substrate atom index: 161 (Symbol: Au), Distance: 3.519 Å
#   - 2D atom index: 232 (Symbol: S) -> Closest Substrate atom index: 193 (Symbol: Au), Distance: 3.313 Å
# Elements in POSCAR: ['S', 'Au', 'Mo']
#
# Calculating average shortest interfacial distance...
#   - 2D atom index: 196 (Symbol: S) -> Closest Substrate atom index: 177 (Symbol: Au), Distance: 3.211 Å
#   - 2D atom index: 198 (Symbol: S) -> Closest Substrate atom index: 9 (Symbol: Au), Distance: 3.078 Å
#   - 2D atom index: 200 (Symbol: S) -> Closest Substrate atom index: 149 (Symbol: Au), Distance: 3.039 Å
#   - 2D atom index: 202 (Symbol: S) -> Closest Substrate atom index: 41 (Symbol: Au), Distance: 3.175 Å
#   - 2D atom index: 204 (Symbol: S) -> Closest Substrate atom index: 181 (Symbol: Au), Distance: 3.125 Å
#   - 2D atom index: 206 (Symbol: S) -> Closest Substrate atom index: 13 (Symbol: Au), Distance: 3.136 Å
#   - 2D atom index: 208 (Symbol: S) -> Closest Substrate atom index: 125 (Symbol: Au), Distance: 3.100 Å
#   - 2D atom index: 210 (Symbol: S) -> Closest Substrate atom index: 153 (Symbol: Au), Distance: 3.097 Å
#   - 2D atom index: 212 (Symbol: S) -> Closest Substrate atom index: 45 (Symbol: Au), Distance: 3.115 Å
#   - 2D atom index: 214 (Symbol: S) -> Closest Substrate atom index: 185 (Symbol: Au), Distance: 3.063 Å
#   - 2D atom index: 216 (Symbol: S) -> Closest Substrate atom index: 17 (Symbol: Au), Distance: 3.217 Å
#   - 2D atom index: 218 (Symbol: S) -> Closest Substrate atom index: 129 (Symbol: Au), Distance: 3.037 Å
#   - 2D atom index: 220 (Symbol: S) -> Closest Substrate atom index: 157 (Symbol: Au), Distance: 3.180 Å
#   - 2D atom index: 222 (Symbol: S) -> Closest Substrate atom index: 49 (Symbol: Au), Distance: 3.079 Å
#   - 2D atom index: 224 (Symbol: S) -> Closest Substrate atom index: 189 (Symbol: Au), Distance: 3.027 Å
#   - 2D atom index: 226 (Symbol: S) -> Closest Substrate atom index: 21 (Symbol: Au), Distance: 3.321 Å
#   - 2D atom index: 228 (Symbol: S) -> Closest Substrate atom index: 133 (Symbol: Au), Distance: 3.001 Å
#   - 2D atom index: 230 (Symbol: S) -> Closest Substrate atom index: 161 (Symbol: Au), Distance: 3.285 Å
#   - 2D atom index: 232 (Symbol: S) -> Closest Substrate atom index: 193 (Symbol: Au), Distance: 3.017 Å
# Elements in POSCAR: ['S', 'Au', 'Mo']
#
# Calculating average shortest interfacial distance...
#   - 2D atom index: 196 (Symbol: S) -> Closest Substrate atom index: 177 (Symbol: Au), Distance: 3.236 Å
#   - 2D atom index: 198 (Symbol: S) -> Closest Substrate atom index: 9 (Symbol: Au), Distance: 3.059 Å
#   - 2D atom index: 200 (Symbol: S) -> Closest Substrate atom index: 149 (Symbol: Au), Distance: 3.112 Å
#   - 2D atom index: 202 (Symbol: S) -> Closest Substrate atom index: 41 (Symbol: Au), Distance: 3.111 Å
#   - 2D atom index: 204 (Symbol: S) -> Closest Substrate atom index: 181 (Symbol: Au), Distance: 3.151 Å
#   - 2D atom index: 206 (Symbol: S) -> Closest Substrate atom index: 13 (Symbol: Au), Distance: 3.116 Å
#   - 2D atom index: 208 (Symbol: S) -> Closest Substrate atom index: 125 (Symbol: Au), Distance: 3.215 Å
#   - 2D atom index: 210 (Symbol: S) -> Closest Substrate atom index: 153 (Symbol: Au), Distance: 3.169 Å
#   - 2D atom index: 212 (Symbol: S) -> Closest Substrate atom index: 45 (Symbol: Au), Distance: 3.049 Å
#   - 2D atom index: 214 (Symbol: S) -> Closest Substrate atom index: 185 (Symbol: Au), Distance: 3.090 Å
#   - 2D atom index: 216 (Symbol: S) -> Closest Substrate atom index: 17 (Symbol: Au), Distance: 3.198 Å
#   - 2D atom index: 218 (Symbol: S) -> Closest Substrate atom index: 129 (Symbol: Au), Distance: 3.155 Å
#   - 2D atom index: 220 (Symbol: S) -> Closest Substrate atom index: 157 (Symbol: Au), Distance: 3.249 Å
#   - 2D atom index: 222 (Symbol: S) -> Closest Substrate atom index: 49 (Symbol: Au), Distance: 3.013 Å
#   - 2D atom index: 224 (Symbol: S) -> Closest Substrate atom index: 189 (Symbol: Au), Distance: 3.054 Å
#   - 2D atom index: 226 (Symbol: S) -> Closest Substrate atom index: 21 (Symbol: Au), Distance: 3.303 Å
#   - 2D atom index: 228 (Symbol: S) -> Closest Substrate atom index: 133 (Symbol: Au), Distance: 3.120 Å
#   - 2D atom index: 230 (Symbol: S) -> Closest Substrate atom index: 161 (Symbol: Au), Distance: 3.352 Å
#   - 2D atom index: 232 (Symbol: S) -> Closest Substrate atom index: 193 (Symbol: Au), Distance: 3.044 Å
# Elements in POSCAR: ['S', 'Au', 'Mo']
#
# Calculating average shortest interfacial distance...
#   - 2D atom index: 196 (Symbol: S) -> Closest Substrate atom index: 9 (Symbol: Au), Distance: 3.434 Å
#   - 2D atom index: 198 (Symbol: S) -> Closest Substrate atom index: 37 (Symbol: Au), Distance: 3.347 Å
#   - 2D atom index: 200 (Symbol: S) -> Closest Substrate atom index: 177 (Symbol: Au), Distance: 3.237 Å
#   - 2D atom index: 202 (Symbol: S) -> Closest Substrate atom index: 41 (Symbol: Au), Distance: 3.364 Å
#   - 2D atom index: 204 (Symbol: S) -> Closest Substrate atom index: 13 (Symbol: Au), Distance: 3.354 Å
#   - 2D atom index: 206 (Symbol: S) -> Closest Substrate atom index: 41 (Symbol: Au), Distance: 3.399 Å
#   - 2D atom index: 208 (Symbol: S) -> Closest Substrate atom index: 153 (Symbol: Au), Distance: 3.256 Å
#   - 2D atom index: 210 (Symbol: S) -> Closest Substrate atom index: 181 (Symbol: Au), Distance: 3.291 Å
#   - 2D atom index: 212 (Symbol: S) -> Closest Substrate atom index: 45 (Symbol: Au), Distance: 3.306 Å
#   - 2D atom index: 214 (Symbol: S) -> Closest Substrate atom index: 17 (Symbol: Au), Distance: 3.296 Å
#   - 2D atom index: 216 (Symbol: S) -> Closest Substrate atom index: 45 (Symbol: Au), Distance: 3.475 Å
#   - 2D atom index: 218 (Symbol: S) -> Closest Substrate atom index: 157 (Symbol: Au), Distance: 3.197 Å
#   - 2D atom index: 220 (Symbol: S) -> Closest Substrate atom index: 185 (Symbol: Au), Distance: 3.369 Å
#   - 2D atom index: 222 (Symbol: S) -> Closest Substrate atom index: 49 (Symbol: Au), Distance: 3.273 Å
#   - 2D atom index: 224 (Symbol: S) -> Closest Substrate atom index: 21 (Symbol: Au), Distance: 3.263 Å
#   - 2D atom index: 226 (Symbol: S) -> Closest Substrate atom index: 49 (Symbol: Au), Distance: 3.571 Å
#   - 2D atom index: 228 (Symbol: S) -> Closest Substrate atom index: 161 (Symbol: Au), Distance: 3.162 Å
#   - 2D atom index: 230 (Symbol: S) -> Closest Substrate atom index: 189 (Symbol: Au), Distance: 3.468 Å
#   - 2D atom index: 232 (Symbol: S) -> Closest Substrate atom index: 25 (Symbol: Au), Distance: 3.253 Å
# Elements in POSCAR: ['S', 'Au', 'Mo']
#
# Calculating average shortest interfacial distance...
#   - 2D atom index: 196 (Symbol: S) -> Closest Substrate atom index: 9 (Symbol: Au), Distance: 3.195 Å
#   - 2D atom index: 198 (Symbol: S) -> Closest Substrate atom index: 37 (Symbol: Au), Distance: 3.055 Å
#   - 2D atom index: 200 (Symbol: S) -> Closest Substrate atom index: 177 (Symbol: Au), Distance: 3.029 Å
#   - 2D atom index: 202 (Symbol: S) -> Closest Substrate atom index: 69 (Symbol: Au), Distance: 3.147 Å
#   - 2D atom index: 204 (Symbol: S) -> Closest Substrate atom index: 13 (Symbol: Au), Distance: 3.109 Å
#   - 2D atom index: 206 (Symbol: S) -> Closest Substrate atom index: 41 (Symbol: Au), Distance: 3.113 Å
#   - 2D atom index: 208 (Symbol: S) -> Closest Substrate atom index: 153 (Symbol: Au), Distance: 3.096 Å
#   - 2D atom index: 210 (Symbol: S) -> Closest Substrate atom index: 181 (Symbol: Au), Distance: 3.088 Å
#   - 2D atom index: 212 (Symbol: S) -> Closest Substrate atom index: 73 (Symbol: Au), Distance: 3.085 Å
#   - 2D atom index: 214 (Symbol: S) -> Closest Substrate atom index: 17 (Symbol: Au), Distance: 3.047 Å
#   - 2D atom index: 216 (Symbol: S) -> Closest Substrate atom index: 45 (Symbol: Au), Distance: 3.195 Å
#   - 2D atom index: 218 (Symbol: S) -> Closest Substrate atom index: 157 (Symbol: Au), Distance: 3.034 Å
#   - 2D atom index: 220 (Symbol: S) -> Closest Substrate atom index: 185 (Symbol: Au), Distance: 3.170 Å
#   - 2D atom index: 222 (Symbol: S) -> Closest Substrate atom index: 77 (Symbol: Au), Distance: 3.049 Å
#   - 2D atom index: 224 (Symbol: S) -> Closest Substrate atom index: 21 (Symbol: Au), Distance: 3.010 Å
#   - 2D atom index: 226 (Symbol: S) -> Closest Substrate atom index: 49 (Symbol: Au), Distance: 3.300 Å
#   - 2D atom index: 228 (Symbol: S) -> Closest Substrate atom index: 161 (Symbol: Au), Distance: 2.997 Å
#   - 2D atom index: 230 (Symbol: S) -> Closest Substrate atom index: 189 (Symbol: Au), Distance: 3.276 Å
#   - 2D atom index: 232 (Symbol: S) -> Closest Substrate atom index: 25 (Symbol: Au), Distance: 3.000 Å
# Elements in POSCAR: ['S', 'Au', 'Mo']
#
# Calculating average shortest interfacial distance...
#   - 2D atom index: 196 (Symbol: S) -> Closest Substrate atom index: 9 (Symbol: Au), Distance: 3.266 Å
#   - 2D atom index: 198 (Symbol: S) -> Closest Substrate atom index: 37 (Symbol: Au), Distance: 3.083 Å
#   - 2D atom index: 200 (Symbol: S) -> Closest Substrate atom index: 177 (Symbol: Au), Distance: 3.149 Å
#   - 2D atom index: 202 (Symbol: S) -> Closest Substrate atom index: 69 (Symbol: Au), Distance: 3.129 Å
#   - 2D atom index: 204 (Symbol: S) -> Closest Substrate atom index: 13 (Symbol: Au), Distance: 3.181 Å
#   - 2D atom index: 206 (Symbol: S) -> Closest Substrate atom index: 41 (Symbol: Au), Distance: 3.140 Å
#   - 2D atom index: 208 (Symbol: S) -> Closest Substrate atom index: 153 (Symbol: Au), Distance: 3.257 Å
#   - 2D atom index: 210 (Symbol: S) -> Closest Substrate atom index: 181 (Symbol: Au), Distance: 3.205 Å
#   - 2D atom index: 212 (Symbol: S) -> Closest Substrate atom index: 73 (Symbol: Au), Distance: 3.067 Å
#   - 2D atom index: 214 (Symbol: S) -> Closest Substrate atom index: 17 (Symbol: Au), Distance: 3.120 Å
#   - 2D atom index: 216 (Symbol: S) -> Closest Substrate atom index: 45 (Symbol: Au), Distance: 3.222 Å
#   - 2D atom index: 218 (Symbol: S) -> Closest Substrate atom index: 157 (Symbol: Au), Distance: 3.198 Å
#   - 2D atom index: 220 (Symbol: S) -> Closest Substrate atom index: 185 (Symbol: Au), Distance: 3.285 Å
#   - 2D atom index: 222 (Symbol: S) -> Closest Substrate atom index: 77 (Symbol: Au), Distance: 3.031 Å
#   - 2D atom index: 224 (Symbol: S) -> Closest Substrate atom index: 21 (Symbol: Au), Distance: 3.085 Å
#   - 2D atom index: 226 (Symbol: S) -> Closest Substrate atom index: 49 (Symbol: Au), Distance: 3.325 Å
#   - 2D atom index: 228 (Symbol: S) -> Closest Substrate atom index: 161 (Symbol: Au), Distance: 3.163 Å
#   - 2D atom index: 230 (Symbol: S) -> Closest Substrate atom index: 189 (Symbol: Au), Distance: 3.386 Å
#   - 2D atom index: 232 (Symbol: S) -> Closest Substrate atom index: 25 (Symbol: Au), Distance: 3.075 Å
# Elements in POSCAR: ['S', 'Au', 'Mo']
#
# Calculating average shortest interfacial distance...
#   - 2D atom index: 196 (Symbol: S) -> Closest Substrate atom index: 37 (Symbol: Au), Distance: 3.383 Å
#   - 2D atom index: 198 (Symbol: S) -> Closest Substrate atom index: 65 (Symbol: Au), Distance: 3.288 Å
#   - 2D atom index: 200 (Symbol: S) -> Closest Substrate atom index: 9 (Symbol: Au), Distance: 3.188 Å
#   - 2D atom index: 202 (Symbol: S) -> Closest Substrate atom index: 97 (Symbol: Au), Distance: 3.409 Å
#   - 2D atom index: 204 (Symbol: S) -> Closest Substrate atom index: 41 (Symbol: Au), Distance: 3.301 Å
#   - 2D atom index: 206 (Symbol: S) -> Closest Substrate atom index: 69 (Symbol: Au), Distance: 3.341 Å
#   - 2D atom index: 208 (Symbol: S) -> Closest Substrate atom index: 181 (Symbol: Au), Distance: 3.215 Å
#   - 2D atom index: 210 (Symbol: S) -> Closest Substrate atom index: 13 (Symbol: Au), Distance: 3.244 Å
#   - 2D atom index: 212 (Symbol: S) -> Closest Substrate atom index: 101 (Symbol: Au), Distance: 3.352 Å
#   - 2D atom index: 214 (Symbol: S) -> Closest Substrate atom index: 45 (Symbol: Au), Distance: 3.243 Å
#   - 2D atom index: 216 (Symbol: S) -> Closest Substrate atom index: 73 (Symbol: Au), Distance: 3.418 Å
#   - 2D atom index: 218 (Symbol: S) -> Closest Substrate atom index: 185 (Symbol: Au), Distance: 3.155 Å
#   - 2D atom index: 220 (Symbol: S) -> Closest Substrate atom index: 17 (Symbol: Au), Distance: 3.323 Å
#   - 2D atom index: 222 (Symbol: S) -> Closest Substrate atom index: 105 (Symbol: Au), Distance: 3.319 Å
#   - 2D atom index: 224 (Symbol: S) -> Closest Substrate atom index: 49 (Symbol: Au), Distance: 3.208 Å
#   - 2D atom index: 226 (Symbol: S) -> Closest Substrate atom index: 77 (Symbol: Au), Distance: 3.516 Å
#   - 2D atom index: 228 (Symbol: S) -> Closest Substrate atom index: 189 (Symbol: Au), Distance: 3.119 Å
#   - 2D atom index: 230 (Symbol: S) -> Closest Substrate atom index: 21 (Symbol: Au), Distance: 3.423 Å
#   - 2D atom index: 232 (Symbol: S) -> Closest Substrate atom index: 53 (Symbol: Au), Distance: 3.199 Å
# Elements in POSCAR: ['S', 'Au', 'Mo']
#
# Calculating average shortest interfacial distance...
#   - 2D atom index: 196 (Symbol: S) -> Closest Substrate atom index: 37 (Symbol: Au), Distance: 3.186 Å
#   - 2D atom index: 198 (Symbol: S) -> Closest Substrate atom index: 65 (Symbol: Au), Distance: 3.039 Å
#   - 2D atom index: 200 (Symbol: S) -> Closest Substrate atom index: 9 (Symbol: Au), Distance: 3.026 Å
#   - 2D atom index: 202 (Symbol: S) -> Closest Substrate atom index: 97 (Symbol: Au), Distance: 3.124 Å
#   - 2D atom index: 204 (Symbol: S) -> Closest Substrate atom index: 41 (Symbol: Au), Distance: 3.099 Å
#   - 2D atom index: 206 (Symbol: S) -> Closest Substrate atom index: 69 (Symbol: Au), Distance: 3.097 Å
#   - 2D atom index: 208 (Symbol: S) -> Closest Substrate atom index: 181 (Symbol: Au), Distance: 3.100 Å
#   - 2D atom index: 210 (Symbol: S) -> Closest Substrate atom index: 13 (Symbol: Au), Distance: 3.084 Å
#   - 2D atom index: 212 (Symbol: S) -> Closest Substrate atom index: 101 (Symbol: Au), Distance: 3.062 Å
#   - 2D atom index: 214 (Symbol: S) -> Closest Substrate atom index: 45 (Symbol: Au), Distance: 3.037 Å
#   - 2D atom index: 216 (Symbol: S) -> Closest Substrate atom index: 73 (Symbol: Au), Distance: 3.179 Å
#   - 2D atom index: 218 (Symbol: S) -> Closest Substrate atom index: 185 (Symbol: Au), Distance: 3.037 Å
#   - 2D atom index: 220 (Symbol: S) -> Closest Substrate atom index: 17 (Symbol: Au), Distance: 3.167 Å
#   - 2D atom index: 222 (Symbol: S) -> Closest Substrate atom index: 105 (Symbol: Au), Distance: 3.026 Å
#   - 2D atom index: 224 (Symbol: S) -> Closest Substrate atom index: 49 (Symbol: Au), Distance: 3.000 Å
#   - 2D atom index: 226 (Symbol: S) -> Closest Substrate atom index: 77 (Symbol: Au), Distance: 3.284 Å
#   - 2D atom index: 228 (Symbol: S) -> Closest Substrate atom index: 189 (Symbol: Au), Distance: 3.001 Å
#   - 2D atom index: 230 (Symbol: S) -> Closest Substrate atom index: 21 (Symbol: Au), Distance: 3.273 Å
#   - 2D atom index: 232 (Symbol: S) -> Closest Substrate atom index: 53 (Symbol: Au), Distance: 2.990 Å
# Elements in POSCAR: ['S', 'Au', 'Mo']
#
# Calculating average shortest interfacial distance...
#   - 2D atom index: 196 (Symbol: S) -> Closest Substrate atom index: 37 (Symbol: Au), Distance: 3.301 Å
#   - 2D atom index: 198 (Symbol: S) -> Closest Substrate atom index: 65 (Symbol: Au), Distance: 3
Å
# Elements in POSCAR: ['S', 'Au', 'Mo']
#
# Calculating average shortest interfacial distance...
#   - 2D atom index: 196 (Symbol: S) -> Closest Substrate atom index: 89 (Symbol: Au), Distance: 3.203 Å
#   - 2D atom index: 198 (Symbol: S) -> Closest Substrate atom index: 121 (Symbol: Au), Distance: 3.192 Å
#   - 2D atom index: 200 (Symbol: S) -> Closest Substrate atom index: 65 (Symbol: Au), Distance: 3.116 Å
#   - 2D atom index: 202 (Symbol: S) -> Closest Substrate atom index: 149 (Symbol: Au), Distance: 3.367 Å
#   - 2D atom index: 204 (Symbol: S) -> Closest Substrate atom index: 93 (Symbol: Au), Distance: 3.283 Å
#   - 2D atom index: 206 (Symbol: S) -> Closest Substrate atom index: 125 (Symbol: Au), Distance: 3.158 Å
#   - 2D atom index: 208 (Symbol: S) -> Closest Substrate atom index: 37 (Symbol: Au), Distance: 3.221 Å
#   - 2D atom index: 210 (Symbol: S) -> Closest Substrate atom index: 69 (Symbol: Au), Distance: 3.081 Å
#   - 2D atom index: 212 (Symbol: S) -> Closest Substrate atom index: 153 (Symbol: Au), Distance: 3.467 Å
#   - 2D atom index: 214 (Symbol: S) -> Closest Substrate atom index: 97 (Symbol: Au), Distance: 3.385 Å
#   - 2D atom index: 216 (Symbol: S) -> Closest Substrate atom index: 129 (Symbol: Au), Distance: 3.149 Å
#   - 2D atom index: 218 (Symbol: S) -> Closest Substrate atom index: 41 (Symbol: Au), Distance: 3.325 Å
#   - 2D atom index: 220 (Symbol: S) -> Closest Substrate atom index: 73 (Symbol: Au), Distance: 3.072 Å
#   - 2D atom index: 222 (Symbol: S) -> Closest Substrate atom index: 161 (Symbol: Au), Distance: 3.434 Å
#   - 2D atom index: 224 (Symbol: S) -> Closest Substrate atom index: 105 (Symbol: Au), Distance: 3.352 Å
#   - 2D atom index: 226 (Symbol: S) -> Closest Substrate atom index: 133 (Symbol: Au), Distance: 3.166 Å
#   - 2D atom index: 228 (Symbol: S) -> Closest Substrate atom index: 49 (Symbol: Au), Distance: 3.291 Å
#   - 2D atom index: 230 (Symbol: S) -> Closest Substrate atom index: 77 (Symbol: Au), Distance: 3.089 Å
#   - 2D atom index: 232 (Symbol: S) -> Closest Substrate atom index: 109 (Symbol: Au), Distance: 3.256 Å
# Elements in POSCAR: ['S', 'Au', 'Mo']
#
# Calculating average shortest interfacial distance...
#   - 2D atom index: 196 (Symbol: S) -> Closest Substrate atom index: 89 (Symbol: Au), Distance: 3.090 Å
#   - 2D atom index: 198 (Symbol: S) -> Closest Substrate atom index: 121 (Symbol: Au), Distance: 3.033 Å
#   - 2D atom index: 200 (Symbol: S) -> Closest Substrate atom index: 65 (Symbol: Au), Distance: 3.047 Å
#   - 2D atom index: 202 (Symbol: S) -> Closest Substrate atom index: 149 (Symbol: Au), Distance: 3.172 Å
#   - 2D atom index: 204 (Symbol: S) -> Closest Substrate atom index: 93 (Symbol: Au), Distance: 3.173 Å
#   - 2D atom index: 206 (Symbol: S) -> Closest Substrate atom index: 125 (Symbol: Au), Distance: 2.997 Å
#   - 2D atom index: 208 (Symbol: S) -> Closest Substrate atom index: 37 (Symbol: Au), Distance: 3.199 Å
#   - 2D atom index: 210 (Symbol: S) -> Closest Substrate atom index: 69 (Symbol: Au), Distance: 3.011 Å
#   - 2D atom index: 212 (Symbol: S) -> Closest Substrate atom index: 153 (Symbol: Au), Distance: 3.278 Å
#   - 2D atom index: 214 (Symbol: S) -> Closest Substrate atom index: 97 (Symbol: Au), Distance: 3.279 Å
#   - 2D atom index: 216 (Symbol: S) -> Closest Substrate atom index: 129 (Symbol: Au), Distance: 2.987 Å
#   - 2D atom index: 218 (Symbol: S) -> Closest Substrate atom index: 41 (Symbol: Au), Distance: 3.304 Å
#   - 2D atom index: 220 (Symbol: S) -> Closest Substrate atom index: 73 (Symbol: Au), Distance: 3.002 Å
#   - 2D atom index: 222 (Symbol: S) -> Closest Substrate atom index: 161 (Symbol: Au), Distance: 3.243 Å
#   - 2D atom index: 224 (Symbol: S) -> Closest Substrate atom index: 105 (Symbol: Au), Distance: 3.244 Å
#   - 2D atom index: 226 (Symbol: S) -> Closest Substrate atom index: 133 (Symbol: Au), Distance: 3.005 Å
#   - 2D atom index: 228 (Symbol: S) -> Closest Substrate atom index: 49 (Symbol: Au), Distance: 3.269 Å
#   - 2D atom index: 230 (Symbol: S) -> Closest Substrate atom index: 77 (Symbol: Au), Distance: 3.019 Å
#   - 2D atom index: 232 (Symbol: S) -> Closest Substrate atom index: 109 (Symbol: Au), Distance: 3.145 Å
# Elements in POSCAR: ['S', 'Au', 'Mo']
#
# Calculating average shortest interfacial distance...
#   - 2D atom index: 196 (Symbol: S) -> Closest Substrate atom index: 89 (Symbol: Au), Distance: 3.298 Å
#   - 2D atom index: 198 (Symbol: S) -> Closest Substrate atom index: 121 (Symbol: Au), Distance: 3.200 Å
#   - 2D atom index: 200 (Symbol: S) -> Closest Substrate atom index: 65 (Symbol: Au), Distance: 3.301 Å
#   - 2D atom index: 202 (Symbol: S) -> Closest Substrate atom index: 149 (Symbol: Au), Distance: 3.290 Å
#   - 2D atom index: 204 (Symbol: S) -> Closest Substrate atom index: 93 (Symbol: Au), Distance: 3.376 Å
#   - 2D atom index: 206 (Symbol: S) -> Closest Substrate atom index: 125 (Symbol: Au), Distance: 3.166 Å
#   - 2D atom index: 208 (Symbol: S) -> Closest Substrate atom index: 65 (Symbol: Au), Distance: 3.482 Å
#   - 2D atom index: 210 (Symbol: S) -> Closest Substrate atom index: 69 (Symbol: Au), Distance: 3.268 Å
#   - 2D atom index: 212 (Symbol: S) -> Closest Substrate atom index: 153 (Symbol: Au), Distance: 3.392 Å
#   - 2D atom index: 214 (Symbol: S) -> Closest Substrate atom index: 97 (Symbol: Au), Distance: 3.475 Å
#   - 2D atom index: 216 (Symbol: S) -> Closest Substrate atom index: 129 (Symbol: Au), Distance: 3.157 Å
#   - 2D atom index: 218 (Symbol: S) -> Closest Substrate atom index: 69 (Symbol: Au), Distance: 3.578 Å
#   - 2D atom index: 220 (Symbol: S) -> Closest Substrate atom index: 73 (Symbol: Au), Distance: 3.259 Å
#   - 2D atom index: 222 (Symbol: S) -> Closest Substrate atom index: 161 (Symbol: Au), Distance: 3.358 Å
#   - 2D atom index: 224 (Symbol: S) -> Closest Substrate atom index: 105 (Symbol: Au), Distance: 3.443 Å
#   - 2D atom index: 226 (Symbol: S) -> Closest Substrate atom index: 133 (Symbol: Au), Distance: 3.174 Å
#   - 2D atom index: 228 (Symbol: S) -> Closest Substrate atom index: 77 (Symbol: Au), Distance: 3.546 Å
#   - 2D atom index: 230 (Symbol: S) -> Closest Substrate atom index: 77 (Symbol: Au), Distance: 3.275 Å
#   - 2D atom index: 232 (Symbol: S) -> Closest Substrate atom index: 109 (Symbol: Au), Distance: 3.349 Å
# Elements in POSCAR: ['S', 'Au', 'Mo']
#
# Calculating average shortest interfacial distance...
#   - 2D atom index: 196 (Symbol: S) -> Closest Substrate atom index: 117 (Symbol: Au), Distance: 3.167 Å
#   - 2D atom index: 198 (Symbol: S) -> Closest Substrate atom index: 149 (Symbol: Au), Distance: 3.150 Å
#   - 2D atom index: 200 (Symbol: S) -> Closest Substrate atom index: 93 (Symbol: Au), Distance: 3.086 Å
#   - 2D atom index: 202 (Symbol: S) -> Closest Substrate atom index: 177 (Symbol: Au), Distance: 3.321 Å
#   - 2D atom index: 204 (Symbol: S) -> Closest Substrate atom index: 121 (Symbol: Au), Distance: 3.248 Å
#   - 2D atom index: 206 (Symbol: S) -> Closest Substrate atom index: 153 (Symbol: Au), Distance: 3.116 Å
#   - 2D atom index: 208 (Symbol: S) -> Closest Substrate atom index: 65 (Symbol: Au), Distance: 3.199 Å
#   - 2D atom index: 210 (Symbol: S) -> Closest Substrate atom index: 97 (Symbol: Au), Distance: 3.051 Å
#   - 2D atom index: 212 (Symbol: S) -> Closest Substrate atom index: 181 (Symbol: Au), Distance: 3.422 Å
#   - 2D atom index: 214 (Symbol: S) -> Closest Substrate atom index: 125 (Symbol: Au), Distance: 3.352 Å
#   - 2D atom index: 216 (Symbol: S) -> Closest Substrate atom index: 157 (Symbol: Au), Distance: 3.107 Å
#   - 2D atom index: 218 (Symbol: S) -> Closest Substrate atom index: 69 (Symbol: Au), Distance: 3.304 Å
#   - 2D atom index: 220 (Symbol: S) -> Closest Substrate atom index: 101 (Symbol: Au), Distance: 3.042 Å
#   - 2D atom index: 222 (Symbol: S) -> Closest Substrate atom index: 189 (Symbol: Au), Distance: 3.389 Å
#   - 2D atom index: 224 (Symbol: S) -> Closest Substrate atom index: 133 (Symbol: Au), Distance: 3.318 Å
#   - 2D atom index: 226 (Symbol: S) -> Closest Substrate atom index: 161 (Symbol: Au), Distance: 3.124 Å
#   - 2D atom index: 228 (Symbol: S) -> Closest Substrate atom index: 77 (Symbol: Au), Distance: 3.269 Å
#   - 2D atom index: 230 (Symbol: S) -> Closest Substrate atom index: 105 (Symbol: Au), Distance: 3.059 Å
#   - 2D atom index: 232 (Symbol: S) -> Closest Substrate atom index: 137 (Symbol: Au), Distance: 3.221 Å
# Elements in POSCAR: ['S', 'Au', 'Mo']
#
# Calculating average shortest interfacial distance...
#   - 2D atom index: 196 (Symbol: S) -> Closest Substrate atom index: 117 (Symbol: Au), Distance: 3.100 Å
#   - 2D atom index: 198 (Symbol: S) -> Closest Substrate atom index: 149 (Symbol: Au), Distance: 3.037 Å
#   - 2D atom index: 200 (Symbol: S) -> Closest Substrate atom index: 93 (Symbol: Au), Distance: 3.064 Å
#   - 2D atom index: 202 (Symbol: S) -> Closest Substrate atom index: 177 (Symbol: Au), Distance: 3.169 Å
#   - 2D atom index: 204 (Symbol: S) -> Closest Substrate atom index: 121 (Symbol: Au), Distance: 3.183 Å
#   - 2D atom index: 206 (Symbol: S) -> Closest Substrate atom index: 153 (Symbol: Au), Distance: 3.001 Å
#   - 2D atom index: 208 (Symbol: S) -> Closest Substrate atom index: 65 (Symbol: Au), Distance: 3.222 Å
#   - 2D atom index: 210 (Symbol: S) -> Closest Substrate atom index: 97 (Symbol: Au), Distance: 3.028 Å
#   - 2D atom index: 212 (Symbol: S) -> Closest Substrate atom index: 181 (Symbol: Au), Distance: 3.275 Å
#   - 2D atom index: 214 (Symbol: S) -> Closest Substrate atom index: 125 (Symbol: Au), Distance: 3.289 Å
#   - 2D atom index: 216 (Symbol: S) -> Closest Substrate atom index: 157 (Symbol: Au), Distance: 2.991 Å
#   - 2D atom index: 218 (Symbol: S) -> Closest Substrate atom index: 69 (Symbol: Au), Distance: 3.326 Å
#   - 2D atom index: 220 (Symbol: S) -> Closest Substrate atom index: 101 (Symbol: Au), Distance: 3.019 Å
#   - 2D atom index: 222 (Symbol: S) -> Closest Substrate atom index: 189 (Symbol: Au), Distance: 3.240 Å
#   - 2D atom index: 224 (Symbol: S) -> Closest Substrate atom index: 133 (Symbol: Au), Distance: 3.254 Å
#   - 2D atom index: 226 (Symbol: S) -> Closest Substrate atom index: 161 (Symbol: Au), Distance: 3.009 Å
#   - 2D atom index: 228 (Symbol: S) -> Closest Substrate atom index: 77 (Symbol: Au), Distance: 3.292 Å
#   - 2D atom index: 230 (Symbol: S) -> Closest Substrate atom index: 105 (Symbol: Au), Distance: 3.037 Å
#   - 2D atom index: 232 (Symbol: S) -> Closest Substrate atom index: 137 (Symbol: Au), Distance: 3.155 Å
